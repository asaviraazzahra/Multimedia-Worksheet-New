# %% [markdown]
# # Tugas Analisis Multimedia: Audio, Gambar, Video
#
# **Mata Kuliah:** Sistem & Teknologi Multimedia
# **Nama:** Asavira Azzahra
# **NIM:** 122140067
#
# ---
#
# ## Deskripsi Tugas
#
# Tugas ini bertujuan untuk memahami representasi dasar data multimedia (audio, gambar, dan video) melalui praktik langsung memuat data, visualisasi, dan ekstraksi informasi fundamental. Anda akan bekerja dengan tiga jenis media berbeda untuk menganalisis karakteristik temporal (audio), spasial (gambar), dan spatio-temporal (video).
#
# Fokus tugas adalah pada pemahaman konsep dasar representasi multimedia dan kemampuan interpretasi hasil visualisasi, **bukan** pada manipulasi atau transformasi lanjutan data multimedia.
#
# ---
#
# ## ⚠️ CATATAN PENTING: PRESENTASI ACAK & KEJUJURAN AKADEMIK
#
# **Sebagian mahasiswa akan dipilih secara ACAK untuk presentasi singkat** (5-10 menit) menjelaskan kode dan interpretasi hasil mereka. Jika Anda:
# - Tidak mampu menjelaskan kode yang Anda kumpulkan
# - Hanya menyalin-tempel tanpa pemahaman
# - Bergantung sepenuhnya pada AI tanpa memahami konsep
#
# **Maka nilai tugas Anda akan diberikan 0 (nol).**
#
# Gunakan referensi dan AI sebagai alat bantu pembelajaran, tetapi pastikan Anda memahami setiap baris kode dan dapat menjelaskan logika di baliknya.

# %%
# Import Library (Satu-satunya sel kode dalam template ini)
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import librosa
import soundfile as sf
from PIL import Image
import cv2
from IPython.display import Audio, HTML, display
import os

# Set matplotlib untuk menampilkan plot inline
# %matplotlib inline

# Tampilkan versi library untuk dokumentasi
print("Library versions:")
print(f"NumPy: {np.__version__}")
print(f"Matplotlib: {matplotlib.__version__}")
print(f"Librosa: {librosa.__version__}")
print(f"OpenCV: {cv2.__version__}")

# Tambahkan import lain jika diperlukan saat mengerjakan tugas
# Out:
# Library versions:
# NumPy: 2.2.4
# Matplotlib: 3.10.1
# Librosa: 0.11.0
# OpenCV: 4.12.0

# %% [markdown]
# ## Petunjuk Umum Pengerjaan
#
# ### 📋 Cara Menggunakan Template
# - Gunakan notebook ini sebagai kerangka kerja utama
# - Tulis penjelasan (markdown) **SEBELUM** menaruh kode agar maksud dan tujuan jelas
# - Tambahkan sel kode di tempat yang sudah disediakan (tandai dengan TODO)
# - Semua plot/gambar harus diberi judul, label sumbu, dan keterangan singkat
#
# ### 📊 Standar Visualisasi
# - Setiap plot harus memiliki judul yang deskriptif
# - Label sumbu X dan Y harus jelas
# - Gunakan colorbar untuk plot yang memerlukan skala warna
# - Berikan interpretasi singkat setelah setiap visualisasi
#
# ### 📂 Struktur Data yang Direkomendasikan
# - Buat folder `data/` di direktori yang sama dengan notebook
# - Gunakan nama file yang deskriptif (contoh: `audio_musik_piano.wav`, `gambar_pemandangan_gunung.jpg`)
# - Dokumentasikan sumber data jika menggunakan dataset publik
#
# ### ⚠️ Larangan
# - **Jangan** menaruh seluruh pekerjaan dalam satu sel kode yang sangat panjang
# - **Jangan** menempel hasil output tanpa interpretasi atau analisis
# - **Jangan** bergantung sepenuhnya pada AI - pahami dan kuasai kode Anda
#
# ### 🎯 Persiapan Presentasi Acak
# - Pastikan Anda memahami setiap baris kode yang ditulis
# - Latih menjelaskan logika dan alur pemikiran Anda
# - Siapkan penjelasan untuk setiap visualisasi dan interpretasinya

# %% [markdown]
# ## Checklist Kelengkapan (Centang ✅ saat selesai)
#
# ### 🎵 Bagian Audio
# - [ ] Muat audio dan tampilkan metadata (durasi, sample rate, jumlah kanal)
# - [ ] Tampilkan waveform dengan label sumbu yang jelas
# - [ ] Tampilkan spectrogram dalam skala log-dB dengan colorbar
# - [ ] Tampilkan MFCC (minimal 13 koefisien) sebagai heatmap
# - [ ] Berikan interpretasi dan analisis untuk setiap visualisasi audio
#
# ### 🖼️ Bagian Gambar
# - [ ] Tampilkan gambar dengan benar dalam format RGB
# - [ ] Tampilkan informasi dasar (dimensi, jumlah kanal, dtype)
# - [ ] Tampilkan histogram warna untuk channel R, G, B
# - [ ] Berikan analisis hubungan histogram dengan kesan visual gambar
#
# ### 📹 Bagian Video
# - [ ] Tampilkan metadata video (resolusi, fps, frame count, durasi)
# - [ ] Tampilkan 3 frame representatif (awal, tengah, akhir)
# - [ ] Konversi BGR ke RGB dengan benar untuk visualisasi
# - [ ] Analisis kesesuaian parameter video dengan use case
#
# ### 📝 Analisis & Dokumentasi
# - [ ] Setiap bagian memiliki interpretasi dan analisis ringkas
# - [ ] Perbandingan representasi ketiga jenis media
# - [ ] Kesimpulan pembelajaran dan refleksi
# - [ ] Semua sumber data dan referensi dicantumkan

# %% [markdown]
# # Pendahuluan
#
# ## Apa itu Data Multimedia?
#
# Data multimedia adalah informasi yang dikodekan dalam berbagai format untuk merepresentasikan dunia nyata:
#
# - **Audio (1D)**: Sinyal satu dimensi yang berubah terhadap waktu
#   - Contoh: musik, suara, speech
#   - Representasi: amplitudo vs waktu
#
# - **Gambar (2D)**: Matriks nilai intensitas dalam ruang dua dimensi
#   - Contoh: foto, ilustrasi, grafik
#   - Representasi: intensitas pixel pada koordinat (x,y)
#
# - **Video (2D + Waktu)**: Rangkaian frame (gambar) yang ditampilkan berurutan
#   - Contoh: film, rekaman, animasi
#   - Representasi: frame berubah terhadap waktu dengan frame rate tertentu
#
# ## Tujuan Tugas
#
# Memahami representasi dasar dan teknik visualisasi fundamental untuk setiap jenis media multimedia, termasuk:
# - Cara memuat dan membaca file multimedia
# - Ekstraksi informasi metadata yang penting
# - Visualisasi yang informatif dan mudah dipahami
# - Interpretasi hasil analisis secara kontekstual
#
# ## Cara Kerja
#
# 1. Isi setiap bagian sesuai instruksi yang diberikan
# 2. Tambahkan sel kode di tempat yang ditandai dengan "TODO"
# 3. Berikan interpretasi dan analisis setelah setiap visualisasi
# 4. Pastikan semua plot memiliki judul, label, dan keterangan yang jelas

# %% [markdown]
# # Bagian A — Audio
#
# ### A1. Deskripsi Data
#
# **TODO:** Jelaskan audio yang akan Anda analisis:
# - Jenis audio: Musik dengan judul Golden - Huntrix
# - Sumber: Youtube [Link Tautan Lagu](https://www.youtube.com/watch?v=yebNIHKAC4A&list=RDyebNIHKAC4A&start_radio=1)
# - Format file: MP3
# - Alasan pemilihan: Karena suka lagunya enak
#
# **Path file:** `data/Golden - Huntrix.mp3`

# %% [markdown]
# ### A2. TODO: Muat & Metadata
#
# **Instruksi:**
# Tulis kode untuk memuat file audio dan menampilkan metadata dasar:
# - Sample rate (Hz)
# - Durasi (detik)
# - Jumlah kanal (mono/stereo)
# - Jumlah total sampel
#
# **Catatan:** Jika file MP3 bermasalah saat loading, gunakan format WAV sebagai alternatif.

# %%
# Memuat file audio dan menampilkan metadata dasar

# Path ke file audio
audio_path = 'data/Golden - Huntrix.mp3'

# Memuat audio menggunakan librosa
try:
    audio_data, sample_rate = librosa.load(audio_path, sr=None, mono=False)  # sr=None untuk mempertahankan sample rate asli
    duration = librosa.get_duration(y=audio_data, sr=sample_rate)  # Durasi dalam detik
    total_samples = audio_data.shape[-1]  # Total jumlah sampel
    num_channels = 1 if len(audio_data.shape) == 1 else audio_data.shape[0]  # Mono atau Stereo

    # Menampilkan metadata
    print(f"Sample rate: {sample_rate} Hz")
    print(f"Durasi: {duration:.2f} detik")
    print(f"Jumlah kanal: {'Mono' if num_channels == 1 else 'Stereo'}")
    print(f"Jumlah total sampel: {total_samples}")

except Exception as e:
    print(f"Error saat memuat file audio: {e}")
# Out:
# Sample rate: 44100 Hz
# Durasi: 198.90 detik
# Jumlah kanal: Stereo
# Jumlah total sampel: 8771584

# %% [markdown]
# ---
#
# ### A3. TODO: Waveform
#
# **Instruksi:**
# Plot waveform audio dengan:
# - Sumbu X: waktu (detik)
# - Sumbu Y: amplitudo
# - Judul dan label sumbu yang jelas
#
# **Analisis yang diperlukan:**
# Jelaskan apa yang Anda lihat dari waveform (pola amplitudo, bagian keras/pelan, dll.)

# %%
# Plot waveform audio

# Path ke file audio
audio_path = 'data/Golden - Huntrix.mp3'

# Memuat audio menggunakan librosa
try:
    audio_data, sample_rate = librosa.load(audio_path, sr=None)  # sr=None untuk mempertahankan sample rate asli
    duration = librosa.get_duration(y=audio_data, sr=sample_rate)  # Durasi dalam detik

    # Membuat array waktu untuk sumbu X
    time = np.linspace(0, duration, len(audio_data))

    # Plot waveform
    plt.figure(figsize=(12, 4))
    plt.plot(time, audio_data, color='blue')
    plt.title('Waveform Audio: Golden - Huntrix')
    plt.xlabel('Waktu (detik)')
    plt.ylabel('Amplitudo')
    plt.grid()
    plt.show()

except Exception as e:
    print(f"Error saat memuat atau memplot file audio: {e}")

# %% [markdown]
# **Analisis dari waveform diatas:**
#
# **Struktur lagu:**
# - Durasi lagu sekitar 200 detik (3 menit 20 detik)
# - Pada sumbu y, kisaran amplitudonya -0.6 sampai +0.6
# - Dan pada sumbu x adalah waktu dan kisaran waktunya 0 sampai 200
#
# **Dinamika Amplitudo:**
# - Dari 0-20 detik, amplitudonya relatif rendah, karena jika didengarkan itu bagian intro musik
# - Di detik 20 -100 mulai rame nih, musiknya udah full, beat sma bass nya udah masuk.
# - Pada detik 100 – 120 detik, tiba-tiba agak turun, musik jadi lebih tenang. Mungkin bagian buat kasih jeda atau transisi, biar kita yg dengar bisa napas bentar.
# - Detik 120 – 175, mulai naik lagi, beat mulai penuh lagi.
# - Pada detik 175 - 200, pelan-pelan mulai turun, musik masuk ke bagian outro.
#
# **Karakteristik Audio:**
# - Ada dua bagian utama yang rame banget, yaitu di menit 20–100 detik dan 120–175 detik.
# - Musiknya punya kontras yang jelas antara bagian yang tenang sama yang full power, khas banget buat genre EDM atau pop.
# - Bentuk gelombangnya rapi dan seimbang di atas-bawah garis nol, tandanya rekamannya stabil dan nggak ada distorsi.
#
# ---

# %% [markdown]
# ### A4. TODO: Spectrogram log-dB
#
# **Instruksi:**
# Hitung STFT dan tampilkan spectrogram dalam skala log-dB:
# - Gunakan parameter standar (n_fft=1024, hop_length=256)
# - Tampilkan dengan colorbar
# - Label sumbu: waktu (detik) dan frekuensi (Hz)
#
# **Analisis yang diperlukan:**
# Jelaskan perbedaan informasi yang didapat dari spectrogram dibanding waveform.

# %%
# Menghitung STFT dan Menampilkan spectrogram dalam skala log-dB

# Path ke file audio
audio_path = 'data/Golden - Huntrix.mp3'

# Muat audio menggunakan librosa
try:
    audio_data, sample_rate = librosa.load(audio_path, sr=None)  # sr=None untuk mempertahankan sample rate asli

    # Hitung STFT
    n_fft = 1024
    hop_length = 256
    stft = librosa.stft(audio_data, n_fft=n_fft, hop_length=hop_length)
    stft_db = librosa.amplitude_to_db(np.abs(stft), ref=np.max)  # Konversi ke skala log-dB

    # Plot spectrogram
    plt.figure(figsize=(12, 6))
    librosa.display.specshow(stft_db, sr=sample_rate, hop_length=hop_length, x_axis='time', y_axis='hz', cmap='viridis')
    plt.colorbar(format='%+2.0f dB')
    plt.title('Spectrogram (log-dB)')
    plt.xlabel('Waktu (detik)')
    plt.ylabel('Frekuensi (Hz)')
    plt.show()

except Exception as e:
    print(f"Error saat memuat atau memproses file audio: {e}")

# %% [markdown]
# **Perbedaan informasi yang didapat dari spectrogram dibanding waveform:**
#
# **Waveform**
# - Waveform itu nunjukin seberapa keras atau pelan suara seiring waktu.
# - Kita bisa lihat kalo pas intro suaranya masih kecil, pas chorus suaranya rame banget dan padat, pas break/tenang volumenya turun lagi.
# - Jadi, waveform tuh fokus ke volume naik-turun sepanjang lagu.
# - Kalo diibaratkan kayak grafik suara naik-turun, mirip kalo liat volume bar yang gerak-gerak.
#
# **Spectogram (peta frekuensi audio)**
# - Spectrogram itu lebih detail, dia nunjukin nada rendah sampai nada tinggi seiring waktu.
# - Warna di spectrogram nunjukin seberapa kuat bunyinya: kuning terang = kenceng, biru/ungu = lemah.
# - Dari sini bisa kelihatan, bass itu nada rendah (di bawah 250 Hz), vokal atau instrumen tengah (500–4000 Hz), efek tinggi (lebih dari 5000 Hz).
# - Jadi spectrogram bisa kasih tau nada apa yang main, bukan cuma keras-pelannya.
# - Ibaratnya spectrogram tuh kayak peta warna musik, bisa keliatan kapan bass nendang, vokal muncul, atau suara tinggi rame.
#
# ---

# %% [markdown]
# ### A5. TODO: MFCC
#
# **Instruksi:**
# Hitung dan tampilkan minimal 13 koefisien MFCC sebagai heatmap:
# - Sumbu X: waktu (frame)
# - Sumbu Y: koefisien MFCC (1-13)
# - Gunakan colorbar dan judul yang jelas
#
# **Analisis yang diperlukan:**
# Interpretasi sederhana: apakah pola MFCC stabil atau berubah-ubah? Apa potensi maknanya?

# %%
# Mengimport library yang diperlukan
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display

# Path ke file audio
audio_path = 'data/Golden - Huntrix.mp3'

try:
    # Muat audio dan hitung MFCC
    audio_data, sample_rate = librosa.load(audio_path, sr=None)
    mfccs = librosa.feature.mfcc(y=audio_data, sr=sample_rate, n_mfcc=13)

    # Plot menggunakan librosa.display.specshow
    plt.figure(figsize=(12, 6))
    img = librosa.display.specshow(
        mfccs, 
        sr=sample_rate,
        x_axis='time',
        y_axis='mel',
        cmap='viridis'
    )
    plt.colorbar(format='%+2.0f')
    plt.title('MFCC (Mel-Frequency Cepstral Coefficients)')
    plt.xlabel('Waktu (detik)')
    plt.ylabel('MFCC Koefisien')
    plt.tight_layout()
    plt.show()

except Exception as e:
    print(f"Error saat memproses MFCC: {e}")

# %% [markdown]
# **Apakah pola MFCC stabil atau berubah-ubah? Apa potensi maknanya?**
#
# Jadi, kalau kita lihat grafik MFCC di lagu Golden – Huntrix, warnanya tuh keliatan cenderung stabil, alias mirip-mirip sepanjang lagu. Artinya, musiknya punya pola yang konsisten, terutama di bagian beat dan instrumen utama.
#
# Ada bagian tertentu (misalnya di menit sekitar 1:40 – 2:00 dan di akhir) yang warnanya agak berubah dan itu nunjukin adanya transisi musik (bagian break atau outro).
#
# - Intro : masih ringan, belum full beat.
# - Break : musik agak turun, lebih tenang.
# - Outro : musik makin pelan dan akhirnya fade out.
#
# Pola MFCC di lagu ini lebih banyak stabil, karena musik elektronik biasanya repetitif dengan beat yang konsisten. Tapi ada juga momen pola berubah (misalnya di break dan outro), yang nunjukin adanya variasi biar lagu nggak monoton.
#
# ---

# %% [markdown]
# ### A6. Analisis Ringkas (Wajib)
#
# **Jawab pertanyaan berikut:**
#
# 1. **Perbedaan insight:** Apa perbedaan informasi yang didapat dari waveform versus spectrogram?
#
#    *Jawaban Anda:*
#    - Kalau lihat waveform, info yang kita dapet tuh lebih ke seberapa keras atau pelan suara di tiap waktu. Jadi keliatan bagian intro yang pelan, terus chorus yang rame, atau pas musik turun lagi.
#    - Sedangkan spectrogram kasih info lebih detail, bukan cuma keras-pelan aja tapi juga nada apa yang main. Dari sini kita bisa lihat kapan bass nendang, kapan vokal nongol, atau kapan suara tinggi kayak hi-hat rame.
#
#    Simplenya, waveform itu kayak grafik volume naik-turun, sedangkan spectrogram itu peta warna musik yang kasih tau isi frekuensinya.
#
# 2. **Pembelajaran dari MFCC:** Apa yang Anda pelajari dari visualisasi MFCC audio ini?
#
#    *Jawaban Anda:*
#
#    Dari MFCC di lagu ini, keliatan polanya cukup stabil sepanjang lagu, karena beat dan instrumen utama repetitif (khas musik elektronik/EDM). Tapi ada juga bagian yang berubah pola, misalnya di transisi kayak break atau outro.
#
#    - MFCC nunjukin kalau lagu ini punya struktur yang konsisten.
#    - Ada variasi di beberapa bagian biar musik nggak monoton.
#    - Pola MFCC ini bisa dibilang kayak sidik jari lagu, karena tiap lagu pasti punya pola uniknya sendiri.
#
# ---

# %% [markdown]
# # Bagian B — Gambar
#
# ### B1. Deskripsi Data
#
# **TODO:** Jelaskan gambar yang akan Anda analisis:
# - Jenis gambar: foto
# - Sumber: foto sendiri
# - Format file: JPG
# - Alasan pemilihan: karena ini fotoku, self love wkwkwk
#
# **Path file:** `data/sunsetbgtyh.jpg`

# %% [markdown]
# ### B2. TODO: Baca & Tampilkan (RGB)
#
# **Instruksi:**
# Baca gambar dan tampilkan dengan benar dalam format RGB:
# - Pastikan konversi warna benar (ingat perbedaan BGR vs RGB di OpenCV)
# - Berikan judul yang deskriptif
# - Hilangkan axis untuk tampilan yang bersih
#
# **Analisis yang diperlukan:**
# Jelaskan gambar secara ringkas (objek dominan, kondisi pencahayaan, komposisi warna).

# %%
try:
    import cv2
    import matplotlib.pyplot as plt
    
    # Membaca gambar dengan OpenCV (dalam format BGR)
    img_path = 'data/sunsetbgtyh.jpg'
    img_bgr = cv2.imread(img_path)
    
    if img_bgr is None:
        raise Exception("Gagal membaca gambar. Pastikan path file benar dan file ada")
    
    # Konversi BGR ke RGB
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    
    # Membuat figure dengan ukuran yang sesuai
    plt.figure(figsize=(10, 8))
    
    # Menampilkan gambar
    plt.imshow(img_rgb)
    plt.title('Foto Self Portrait dengan Latar Sunset', pad=20)
    
    # Menghilangkan axis
    plt.axis('off')
    
    # Mengatur layout
    plt.tight_layout()
    
    # Menampilkan plot
    plt.show()

except Exception as e:
    print(f"Error: {e}")
    print("Pastikan:")
    print("1. File gambar ada di folder 'data/'")
    print("2. Nama file dan ekstensi benar (.jpg)")
    print("3. Path ke file benar")

# %% [markdown]
# **Analisis Gambar:**
#
# 1. **Objek Dominan:**
#    - Subjek utamanya foto self portrait yaitu foto saya sendiri
#    - Latar belakang pada gambar adalah pemandangan sunset/matahari terbenam.
#    - Elemen lain yang terlihat adalah embung A, karena saya emang foto disitu
#
# 2. **Kondisi Pencahayaan:**
#    - Pencahayaan alami dari cahaya matahari terbenam atau sunset, fotonya juga menggunakan blitz dari kameranya
#    - Arah cahaya backlight/dari belakang subjek
#    - Efek pencahayaan pada subjek: blitz dari hp
#
# 3. **Komposisi Warna:**
#    - Warna dominan: orange dan warna cerah dari langit
#    - Gradasi warna langit: kuning ke orange, ada hint warna ungu muda dan putih
#
# ---

# %% [markdown]
# ### B3. TODO: Informasi Dasar
#
# **Instruksi:**
# Tampilkan informasi metadata gambar:
# - Dimensi (Height × Width)
# - Jumlah kanal
# - Tipe data (dtype)
# - Mode warna (jika relevan)
# - Ukuran file dalam memori
#
# **Analisis yang diperlukan:**
# Jelaskan mengapa informasi ini penting untuk tahap preprocessing atau analisis lanjutan.

# %%
try:
    import cv2
    import os
    
    # Membaca gambar
    img_path = 'data/sunsetbgtyh.jpg'
    img = cv2.imread(img_path)
    
    if img is None:
        raise Exception("Gagal membaca gambar")
    
    # Mengambil informasi metadata
    height, width, channels = img.shape
    dtype = img.dtype
    file_size = os.path.getsize(img_path) / 1024  # Konversi ke KB
    
    # Menampilkan informasi
    print("=== Informasi Metadata Gambar ===")
    print(f"Dimensi: {height} × {width} pixel")
    print(f"Jumlah kanal: {channels}")
    print(f"Tipe data: {dtype}")
    print(f"Mode warna: BGR (OpenCV default)")
    print(f"Ukuran file: {file_size:.2f} KB")
    print(f"Ukuran di memori: {(height * width * channels) / 1024:.2f} KB")

except Exception as e:
    print(f"Error: {e}")
# Out:
# === Informasi Metadata Gambar ===
# Dimensi: 3630 × 2042 pixel
# Jumlah kanal: 3
# Tipe data: uint8
# Mode warna: BGR (OpenCV default)
# Ukuran file: 4996.99 KB
# Ukuran di memori: 21716.19 KB

# %% [markdown]
# **Mengapa informasi ini penting untuk tahap preprocessing atau analisis lanjutan**
#
# 1. **Dimensi (Height × Width)**
#    - Ini ukuran panjang × lebar gambar.
#    - Penting buat tau butuh memori berapa, gampangin pas gambar mau di-resize, dan biar aspek rasio (proporsi panjang-lebar) tetap pas.
#
# 2. **Jumlah kanal**
#
#    Kanal itu jumlah “lapisan warna” di gambar.
#    - Hitam-putih = 1 kanal.
#    - Warna biasa (RGB) = 3 kanal.
#    - Kalau ada transparansi (RGBA) = 4 kanal.
#
#    Info ini penting banget buat konversi mode warna dan ngaruh ke ukuran memori yang dipakai.
#
# 3. **Tipe Data (dtype)**
#    - Ini ngatur presisi angka tiap pixel, misalnya nilainya bisa 0–255 atau bentuk desimal.
#    - Penting kalau mau normalisasi data atau menyesuaikan sama algoritma tertentu.
#
# 4. **Mode Warna**
#    - Mode ini nunjukin cara gambar ditampilkan, misalnya BGR, RGB, atau grayscale.
#    - Penting biar nggak salah warna pas diolah atau ditampilkan (misalnya merah jadi biru kalau salah mode)
#
# 4. **Ukuran file**
#    - Nunjukin seberapa besar file gambar di penyimpanan/ram.
#    - Penting buat optimasi, terutama kalau sistem atau device punya memori terbatas.
#    - Makin kecil dan efisien, makin gampang juga diproses.
#
# ---

# %% [markdown]
# ### B4. TODO: Histogram Warna
#
# **Instruksi:**
# Tampilkan histogram distribusi intensitas untuk channel R, G, B:
# - Range: 0-255
# - Plot terpisah atau overlay dengan warna sesuai channel
# - Label sumbu: intensitas pixel dan frekuensi
# - Legend yang jelas
#
# **Analisis yang diperlukan:**
# Analisis: channel mana yang dominan? Bagaimana kontras gambar? Seperti apa sebaran intensitasnya?

# %%
try:
    import cv2
    import numpy as np
    import matplotlib.pyplot as plt
    
    # Membaca gambar
    img_path = 'data/sunsetbgtyh.jpg'
    img = cv2.imread(img_path)
    
    if img is None:
        raise Exception("Gagal membaca gambar")

    # Memisahkan channel BGR
    b, g, r = cv2.split(img)
    
    # Membuat figure dengan ukuran yang sesuai
    plt.figure(figsize=(12, 6))
    
    # Plot histogram untuk setiap channel
    plt.hist(r.ravel(), bins=256, range=[0, 256], color='red', alpha=0.7, label='Red Channel')
    plt.hist(g.ravel(), bins=256, range=[0, 256], color='green', alpha=0.7, label='Green Channel')
    plt.hist(b.ravel(), bins=256, range=[0, 256], color='blue', alpha=0.7, label='Blue Channel')

    # Menambahkan label dan judul
    plt.xlabel('Intensitas Pixel')
    plt.ylabel('Frekuensi')
    plt.title('Histogram Distribusi Warna RGB')
    plt.legend()
    plt.grid(True, alpha=0.2)
    
    # Mengatur layout
    plt.tight_layout()
    
    # Menampilkan plot
    plt.show()

except Exception as e:
    print(f"Error: {e}")

# %% [markdown]
# **Analisis Histogram Warna**
#
# 1. **Warna yang paling dominan**
#    - Dari grafik, warna biru kelihatan paling banyak dan menyebar luas dari gelap sampai terang
#    - Warna hijau muncul cukup kuat di bagian terang (sekitar 150–180)
#    - Warna merah lebih banyak ada di bagian gelap dan menengah (sekitar 30–130).
#
#    Jadi, gambar ini lebih banyak didominasi oleh biru, sedangkan hijau dan merah ikut menambah nuansa.
#
#
# 2. **Kontras Gambar**
#    Karena warna-warna tersebar dari bagian gelap sampai terang, gambar punya kontras yang bagus. Artinya, detail di area gelap maupun terang sama-sama kelihatan.
#
# 3. **Sebaran Warna**
#    - Merah: lebih terkumpul di bagian gelap–menengah.
#    - Hijau: lebih sering di area terang.
#    - Biru: menyebar paling luas, dari gelap sampai terang → bikin biru jadi warna yang paling mendominasi.
#
# ---

# %% [markdown]
# ### B5. Analisis Ringkas (Wajib)
#
# **Jawab pertanyaan berikut:**
#
# **Relasi histogram dengan kesan visual:** Apa hubungan antara pola histogram yang Anda lihat dengan kesan visual gambar (terang/gelap, warna dominan, kontras)?
#
# *Jawaban Anda:* Pola histogramnya nunjukin kalau warna biru lumayan dominan dan nyebar luas, jadi gambar keliatan agak kebiruan. Warna hijau banyak muncul di bagian terang, bikin langit atau highlight jadi lebih hidup. Sementara warna merah lebih sering nongol di area gelap, kasih kesan hangat di bayangan. Karena sebaran warnanya merata dari gelap sampai terang, gambar ini punya kontras yang oke, detailnya jelas, dan warnanya kelihatan lebih hidup.
#
# ---

# %% [markdown]
# # Bagian C — Video
#
# ### C1. Deskripsi Data
#
# **TODO:** Jelaskan video yang akan Anda analisis:
# - Jenis video: pemandangan view sunset
# - Sumber: rekaman sendiri
# - Durasi target: 19 detik
# - Alasan pemilihan: Karena bagus dan indah
#
# **Path file:** `data/vidsunset.mp4`

# %% [markdown]
# ### C2. TODO: Baca & Metadata
#
# **Instruksi:**
# Baca video dengan OpenCV dan tampilkan metadata:
# - Resolusi (Width × Height)
# - Frame rate (fps)
# - Jumlah total frame
# - Durasi (detik)
# - Klasifikasi resolusi (HD, Full HD, 4K, dll.)
#
# **Analisis yang diperlukan:**
# Jelaskan pentingnya parameter-parameter tersebut untuk analisis video atau aplikasi tertentu.

# %%
try:
    import cv2
    import math

    # Membaca video
    video_path = 'data/vidsunset.mp4'
    cap = cv2.VideoCapture(video_path)

    if not cap.isOpened():
        raise Exception("Error: Tidak dapat membuka video")

    # Mengambil metadata video
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    duration = total_frames / fps

    # Menentukan klasifikasi resolusi
    def classify_resolution(w, h):
        if w >= 3840 and h >= 2160:
            return "4K Ultra HD"
        elif w >= 2560 and h >= 1440:
            return "2K Quad HD"
        elif w >= 1920 and h >= 1080:
            return "Full HD (1080p)"
        elif w >= 1280 and h >= 720:
            return "HD (720p)"
        else:
            return "Standard Definition"

    # Menampilkan informasi
    print("=== Metadata Video ===")
    print(f"Resolusi: {width} × {height} pixel")
    print(f"Frame rate: {fps} fps")
    print(f"Jumlah frame: {total_frames}")
    print(f"Durasi: {duration:.2f} detik ({math.floor(duration/60)}:{int(duration%60)} menit)")
    print(f"Klasifikasi resolusi: {classify_resolution(width, height)}")

    # Menutup video
    cap.release()

except Exception as e:
    print(f"Error: {e}")
# Out:
# === Metadata Video ===
# Resolusi: 720 × 1280 pixel
# Frame rate: 59 fps
# Jumlah frame: 1155
# Durasi: 19.58 detik (0:19 menit)
# Klasifikasi resolusi: Standard Definition

# %% [markdown]
# **Analisis Parameter Video**
#
# 1. **Resolusi (Width × Height)**
#
#    Ini nunjukin seberapa detail kualitas gambar di video. Makin tinggi resolusi, makin tajam gambarnya. Resolusi ini penting buat nyesuain sama layar yang dipakai, ukuran file, dan seberapa cepat video bisa diproses.
#
# 2. **Frame Rate (fps)**
#
#    Ini jumlah gambar per detik yang ditampilin. Makin tinggi fps, makin halus gerakannya. Contohnya:
#    - Game biasanya butuh 30–60 fps biar smooth.
#    - Film cukup 24 fps karena itu udah standar sinematik.
#    - CCTV kadang pakai 15 fps biar hemat tempat penyimpanan.
#
# 3. **Total Frame & Durasi**
#
#    Ini dipakai buat ngitung berapa lama video berjalan, seberapa besar butuh storage, dan berapa lama proses render atau editingnya.
#
# 4. **Klasifikasi Resolusi**
#
#    Setiap level resolusi punya fungsi masing-masing:
#    - HD (720p): pas buat nonton di HP atau streaming ringan.
#    - Full HD (1080p): standar umum buat nonton di laptop/TV.
#    - 4K: dipakai buat konten premium atau profesional karena super detail.
#
# ---

# %% [markdown]
# ### C3. TODO: Tampilkan 3 Frame (Awal–Tengah–Akhir)
#
# **Instruksi:**
# Ambil dan tampilkan 3 frame representatif:
# - Frame pertama (index 0)
# - Frame tengah (index ~total_frame/2)
# - Frame terakhir (index total_frame-1)
# - **Konversi BGR→RGB** sebelum ditampilkan
# - Subplot dengan judul frame dan timestamp
#
# **Analisis yang diperlukan:**
# Deskripsikan perbedaan visual antar frame dan apa yang dapat dipelajari dari sampel frame ini.

# %%
try:
    import cv2
    import matplotlib.pyplot as plt

    # Membaca video
    video_path = 'data/vidsunset.mp4'
    cap = cv2.VideoCapture(video_path)

    if not cap.isOpened():
        raise Exception("Error: Tidak dapat membuka video")

    # Mengambil total frame dan fps
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    
    # Indeks frame yang akan diambil
    frames_idx = [0, total_frames//2, total_frames-1]
    frames = []
    timestamps = []

    # Mengambil frame
    for idx in frames_idx:
        cap.set(cv2.CAP_PROP_POS_FRAMES, idx)
        ret, frame = cap.read()
        if ret:
            # Konversi BGR ke RGB
            frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frames.append(frame_rgb)
            # Menghitung timestamp
            timestamp = idx / fps
            timestamps.append(f"{int(timestamp//60)}:{int(timestamp%60):02d}")

    # Membuat subplot
    plt.figure(figsize=(15, 5))
    
    for i in range(3):
        plt.subplot(1, 3, i+1)
        plt.imshow(frames[i])
        plt.title(f'Frame {frames_idx[i]}\nTimestamp: {timestamps[i]}')
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()

    # Menutup video
    cap.release()

except Exception as e:
    print(f"Error: {e}")

# %% [markdown]
# **Analisis Frame Video**
#
# **Frame Awal (Frame 0)**
# Di awal video, matahari masih lumayan tinggi jadi pencahayaannya terang banget.
#
# **Frame Tengah**
# Masuk ke bagian tengah, cahayanya pelan-pelan berubah. Matahari mulai turun, warna langit juga berubah jadi lebih hangat—kayak ada campuran kuning-orange.
#
# **Frame Akhir**
# Di akhir video, udah jelas banget momen sunset. Matahari makin rendah, cahayanya redup, dan langit berubah dominan orange kemerahan.
#
# ---

# %% [markdown]
# ### C4. Analisis Ringkas (Wajib)
#
# **Jawab pertanyaan berikut:**
#
# **Kesesuaian parameter:** Apakah fps dan resolusi video ini sesuai untuk use case pilihan Anda (misalnya: media sosial, kuliah daring, presentasi, dll.)? Jelaskan alasan singkat.
#
# *Jawaban Anda:* Walaupun secara teknis masih dihitung Standard Definition, video ini udah optimal banget buat sosmed. Formatnya vertikal, durasinya pas, dan kualitas gambarnya cukup tajam buat HP. Singkatnya: tinggal upload aja, udah cocok banget buat Instagram atau TikTok.
#
# ---

# %% [markdown]
# # Perbandingan & Kesimpulan
#
# ## Perbandingan Representasi Media
#
# **TODO:** Bandingkan secara ringkas representasi dan visualisasi ketiga media:
#
# ### Audio (1D - Temporal)
# - Representasi: Audio itu data 1 dimensi yang jalan seiring waktu, biasanya disimpan sebagai array angka.
# - Visualisasi utama: Waveform untuk nunjukin keras-lembut suara sepanjang waktu, spectrogram untuk nunjukin nada rendah–tinggi (frekuensi) seiring waktu kemudian MFCC buat ngeliat ciri khas suara, semacam sidik jari musik.
# - Informasi yang diperoleh: kita bisa tahu pola volume, isi frekuensi, sampai karakter musiknya.
#
# ### Gambar (2D - Spasial)
# - Representasi: Gambar itu data 2 dimensi, berupa matriks pixel (tinggi × lebar × warna).
# - Visualisasi utama: tampilan RGB biasa, histogram warna buat ngeliat sebaran intensitas tiap channel, metadata kayak resolusi dan format file.
# - Informasi yang diperoleh: warna dominan, distribusi terang-gelap, dan bentuk objek di gambar.
#
# ### Video (2D + Waktu - Spatio-temporal)
# - Representasi: Video itu gabungan gambar 2D yang bergerak seiring waktu.
# - Visualisasi utama: bisa dianalisis lewat sampling frame (awal, tengah, akhir), dan Metadata (fps, resolusi, durasi).
# - Informasi yang diperoleh: Dari sini, kita bisa tahu perubahan visual dari waktu ke waktu, seberapa halus gerakannya, dan kualitas rekamannya.
#
# ---
#
# ## Refleksi Pembelajaran
#
# ### 3 Poin yang Saya Pelajari:
# 1. Setiap jenis media (audio, gambar, video) punya ciri khasnya masing-masing, jadi cara bacanya juga beda. Misalnya klo audio dilihat dari waveform atau spectrogram, gambar dilihat dari warna dan pixel, sementara video gabungan keduanya plus waktu.
# 2. Metadata itu ternyata penting banget deh. Info kayak resolusi, fps, atau format bisa bantu kita bisa ngerti lebih dalam soal kualitas dan kebutuhan proses data.
# 3. Representasi data yang bentuknya angka-angka sebenernya nyambung langsung sama cara kita melihat dan mendengar. Jadi apa yang kita analisis di komputer punya hubungan sama persepsi manusia.
#
# ### 2 Hal yang Masih Membingungkan/Ingin Diperdalam:
# 1. Gimana cara kompresi video biar ukuran file kecil tapi kualitas tetap bagus, kaya video netflix atau youtube?
# 2. Gimana cara memisahkan instrumen atau vokal dari satu file audio
#
# ---
#
# ## Sumber Data & Referensi
#
# **TODO:** Cantumkan semua sumber data dan referensi yang digunakan:
#
# - **Audio:** Youtube [Link Tautan Lagu](https://www.youtube.com/watch?v=yebNIHKAC4A&list=RDyebNIHKAC4A&start_radio=1)
# - **Gambar:** Fotoku sendiri
# - **Video:** Video yang aku rekam sendiri
# - **Referensi teknis:** dokumentasi OPenCV, dokumentasi librosa, Matplotlib visualization guide, NumPy documentation

# %% [markdown]
# # Rubrik Penilaian
#
# ## Distribusi Bobot Penilaian
#
# | **Aspek Penilaian** | **Bobot** | **Deskripsi** |
# |---|---|---|
# | **Kelengkapan** | **35%** | Semua langkah inti dikerjakan sesuai checklist |
# | **Kualitas Visualisasi** | **20%** | Judul, label sumbu, colorbar, legend, keterbacaan plot |
# | **Analisis & Interpretasi** | **30%** | Kemampuan interpretasi hasil, bukan sekadar output mentah |
# | **Kerapihan & Struktur** | **10%** | Markdown jelas, kode modular, dokumentasi baik |
# | **Orisinalitas & Penguasaan** | **5%** | Pemahaman saat presentasi acak |
#
# ---
#
# ## Detail Kriteria Penilaian
#
# ### 🏆 Kelengkapan (35%)
# - ✅ Semua 4 visualisasi audio (metadata, waveform, spectrogram, MFCC)
# - ✅ Semua 3 visualisasi gambar (display RGB, metadata, histogram)
# - ✅ Semua 2 visualisasi video (metadata, frame extraction)
# - ✅ Analisis ringkas untuk setiap bagian
#
# ### 📊 Kualitas Visualisasi (20%)
# - Plot memiliki judul yang informatif dan deskriptif
# - Label sumbu X dan Y jelas dan sesuai
# - Colorbar/legend tersedia jika diperlukan
# - Ukuran plot proporsional dan mudah dibaca
#
# ### 🧠 Analisis & Interpretasi (30%)
# - Interpretasi menunjukkan pemahaman konsep
# - Analisis kontekstual, bukan sekadar deskripsi output
# - Mampu menghubungkan hasil dengan teori
# - Refleksi pembelajaran yang thoughtful
#
# ### 📝 Kerapihan & Struktur (10%)
# - Markdown terstruktur dengan heading yang konsisten
# - Kode bersih, terkompartemen, dan mudah dibaca
# - Dokumentasi yang memadai
# - Flow logical dari satu bagian ke bagian lain
#
# ### 🎯 Orisinalitas & Penguasaan (5%)
# - **PENTING:** Jika saat presentasi acak Anda tidak mampu menjelaskan kode yang Anda tulis atau menunjukkan ketergantungan buta pada AI/copy-paste, **nilai tugas akan dianggap 0**.
# - Kemampuan menjelaskan logika dan alur pemikiran
# - Pemahaman konsep di balik implementasi kode
#
# ## Proporsi Penilaian Total
# - Proporsi penilaian hanya 80%, 20% lagi akan didasarkan pada kecepatan pengumpulan tugas
# - Sehingga: 0.8 * penilaian dosen + nilai waktu pengumpulan

# %% [markdown]
# # Aturan Kejujuran Akademik
#
# ## 📖 Penggunaan Referensi & AI yang Diperbolehkan
#
# Anda **BOLEH** menggunakan:
# - ✅ Dokumentasi resmi library (NumPy, Matplotlib, Librosa, OpenCV)
# - ✅ Tutorial dan contoh kode dari sumber terpercaya
# - ✅ AI tools (ChatGPT, GitHub Copilot, dll.) sebagai **alat bantu pembelajaran**
# - ✅ Diskusi dengan teman untuk pemahaman konsep
#
# ## ⚠️ Syarat & Batasan WAJIB
#
# Namun Anda **HARUS**:
# - 🧠 **Memahami setiap baris kode** yang Anda masukkan ke notebook
# - 📝 **Menulis interpretasi dengan kata-kata sendiri**, bukan hasil copy-paste
# - 📚 **Mencantumkan sumber data dan referensi** yang digunakan, termasuk transkrip percakapan dengan AI dalam link atau teks
# - 🎯 **Mampu menjelaskan logika dan alur pemikiran** saat presentasi acak
#
# ## ❌ Pelanggaran yang Berakibat Nilai 0
#
# - **Plagiarisme atau penyalinan buta** dari sumber manapun
# - **Copy-paste kode tanpa pemahaman** dan tidak dapat menjelaskan
# - **Menggunakan AI untuk mengerjakan seluruh tugas** tanpa pembelajaran personal
# - **Tidak dapat menjawab pertanyaan dasar** tentang kode yang dikumpulkan
# - **Menyalin pekerjaan teman** atau bekerjasama dalam pengerjaan individual
#
# ## 🎯 Persiapan Presentasi Acak
#
# **Kemungkinan pertanyaan yang akan ditanyakan:**
# - "Jelaskan mengapa Anda menggunakan parameter ini di STFT?"
# - "Apa arti dari pola yang terlihat di MFCC?"
# - "Mengapa perlu konversi BGR ke RGB?"
# - "Interpretasikan hasil histogram yang Anda buat"
# - "Bagaimana cara kerja spectrogram?"
#
# **Tips sukses:**
# - Pahami konsep dasar setiap teknik yang digunakan
# - Latih menjelaskan dengan bahasa sederhana
# - Siapkan justifikasi untuk setiap pilihan parameter
# - Kuasai interpretasi setiap visualisasi yang dibuat

# %% [markdown]
# # Panduan Pengumpulan
#
# ## 📁 Berkas yang Harus Dikumpulkan
#
# ### Wajib:
# 1. **Notebook Jupyter** (.ipynb) dengan nama: `NIM_Nama_TugasMultimedia.ipynb`
#    - Contoh: `123456789_JohnDoe_TugasMultimedia.ipynb`
# 2. **PDF hasil render dari notebook**
#
# ---
#
# ## 📅 Informasi Pengumpulan
#
# ---
#
# ## ✅ Checklist Sebelum Submit
#
# - [✅] Semua cell sudah dijalankan dan menampilkan output
# - [✅] Nama file sesuai format: `NIM_Worksheet2.ipynb` dan `NIM_Worksheet2.pdf`
# - [✅] Semua TODO sudah diisi dengan lengkap
# - [✅] Analisis dan interpretasi sudah ditulis untuk setiap bagian
# - [✅] Sumber data dan referensi sudah dicantumkan
#
# ---
#
# ### Export ke PDF:
# - File → Save and Export Notebook As →  HTML
# - Buka HTML di browser -> Save as PDF
